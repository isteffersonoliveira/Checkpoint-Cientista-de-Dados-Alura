# %% [markdown]
# # Exemplo de Notebook - Python Fundamentos
#
# Este é um template de exemplo para organizar notebooks do curso.
#
# **Módulo:** Python Fundamentos
# **Tópico:** Introdução ao Python
# **Autor:** Stefferson Oliveira
# **Data:** 2025

# %% [markdown]
# ## 📋 Objetivos
#
# - Objetivo 1
# - Objetivo 2
# - Objetivo 3

# %% [markdown]
# ## 📚 Importação de Bibliotecas

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Configurações de visualização
sns.set_theme(style='darkgrid', palette='husl')
# %matplotlib inline

# %% [markdown]
# ## 🎯 Exercício 1: Título do Exercício
#
# Descrição do exercício...

# %%
# Seu código aqui

# %% [markdown]
# ## 🎯 Exercício 2: Título do Exercício
#
# Descrição do exercício...

# %%
# Seu código aqui

# %% [markdown]
# ## 📊 Conclusões
#
# Principais aprendizados:
# - Aprendizado 1
# - Aprendizado 2
# - Aprendizado 3

# %% [markdown]
# ## 📚 Referências
#
# - [Documentação Python](https://docs.python.org/pt-br/3/)
# - [NumPy Documentation](https://numpy.org/doc/)
# - [Pandas Documentation](https://pandas.pydata.org/docs/)
